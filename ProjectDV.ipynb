# %%
import pandas as pd
import numpy as np

# %%
data_gdp = pd.read_csv('A:\kbtu\GDP_annual_growth_NEW.csv')

# %%
data_gdp
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code  1960      1961      1962      1963       1964  \
# ...

# %%
co2 = pd.read_csv('A:\kbtu\CO2_emission.csv')

# %%
co2
# Out:
#      Country Name country_code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name      1990      1991      1992  \
# 0    CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1    CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# ...

# %%
death = pd.read_csv(r'A:\kbtu\total-cancer-deaths-by-type.csv')

# %%
death
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Liver cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                                   851
# 1                                                   866
# 2                                                   890
# 3                                                   914
# 4                                                   933
# ...                                                 ...
# 6835                                                948
# 6836                                                966
# 6837                                                982
# ...

# %% [markdown]
# <h1>Death</h1>

# %%
death = death.loc[:,['Entity', 'Year', 'Deaths - Tracheal, bronchus, and lung cancer - Sex: Both - Age: All Ages (Number)']]
death
# Out:
#            Entity  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 6835     Zimbabwe  2015
# 6836     Zimbabwe  2016
# 6837     Zimbabwe  2017
# 6838     Zimbabwe  2018
# 6839     Zimbabwe  2019
#
#       Deaths - Tracheal, bronchus, and lung cancer - Sex: Both - Age: All Ages (Number)
# 0                                                   983
# 1                                                   982
# 2                                                   989
# 3                                                   995
# 4                                                   996
# ...                                                 ...
# 6835                                                902
# 6836                                                932
# 6837                                                960
# 6838                                                993
# ...

# %%
death=death.pivot(index='Entity', columns='Year')

# %%
death
# Out:
#                                Deaths - Tracheal, bronchus, and lung cancer - Sex: Both - Age: All Ages (Number)  \
# Year                                                                                                        1990
# Entity
# Afghanistan                                                                   983
# African Region (WHO)                                                        22506
# Albania                                                                       622
# Algeria                                                                      1420
# American Samoa                                                                  6
# ...                                                                           ...
# World Bank Lower Middle Income                                             135241
# World Bank Upper Middle Income                                             431510
# Yemen                                                                         475
# ...

# %%
death['Deaths - Tracheal, bronchus, and lung cancer - Sex: Both - Age: All Ages (Number)'].columns
# Out:
# Int64Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
#            dtype='int64', name='Year')

# %%
death.columns
# Out:
# Int64Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
#            dtype='int64', name='Year')

# %% [markdown]
# <h1>data_gdp</h1>

# %%
data_gdp
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code  1960      1961      1962      1963       1964  \
# ...

# %%
data_gdp_info = data_gdp.iloc[:,0:4]

# %%
data_gdp_info
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code
# 0    NY.GDP.MKTP.KD.ZG
# 1    NY.GDP.MKTP.KD.ZG
# 2    NY.GDP.MKTP.KD.ZG
# 3    NY.GDP.MKTP.KD.ZG
# ...

# %%
data_gdp_years = data_gdp.iloc[:,34:]

# %%
data_gdp_years
# Out:
#          1991      1992       1993      1994       1995       1996      1997  \
# 0    7.962872  5.882353   7.307692  8.203903   2.547144   1.185788  7.046874
# 1   -0.186462 -2.514585  -1.354085  1.943575   4.445560   5.618804  3.336851
# 2         NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 3    1.123940  2.695885  -1.148545 -0.296739   1.971769   4.652554  3.708612
# 4    0.991359 -5.838281 -23.983417  1.339363  15.000000  13.544370  7.274277
# ..        ...       ...        ...       ...        ...        ...       ...
# 261       NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 262  6.293494  8.207598   4.001966  6.721949   5.669371   4.634967  5.231112
# 263 -1.018220 -2.137057   1.233520  3.200001   3.099995   4.299999  2.600002
# 264 -0.036133 -1.730922   6.797274 -8.625442   2.897669   6.218546  3.814007
# 265  5.531782 -9.015570   1.051459  9.235199   0.158026  10.360697  2.680594
#
# ...

# %%
data_gdp_years_res = pd.concat([data_gdp_info, data_gdp_years], axis=1)

# %%
data_gdp_years_res
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code      1990      1991      1992       1993      1994  \
# ...

# %% [markdown]
# <h1>co2</h1>

# %%
co2
# Out:
#      Country Name country_code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name      1990      1991      1992  \
# 0    CO2 emissions (metric tons per capita)       NaN       NaN       NaN
# 1    CO2 emissions (metric tons per capita)  0.191745  0.167682  0.095958
# ...

# %%
for col in co2.columns:
    pct_missing = np.mean(co2[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Country Name - 0%
# country_code - 0%
# Region - 0%
# Indicator Name - 0%
# 1990 - 14%
# 1991 - 13%
# 1992 - 12%
# 1993 - 12%
# 1994 - 12%
# 1995 - 12%
# 1996 - 12%
# 1997 - 12%
# 1998 - 12%
# 1999 - 12%
# 2000 - 12%
# 2001 - 12%
# 2002 - 11%
# 2003 - 11%
# 2004 - 11%
# 2005 - 11%
# 2006 - 11%
# 2007 - 11%
# 2008 - 11%
# 2009 - 11%
# 2010 - 11%
# 2011 - 11%
# 2012 - 11%
# 2013 - 11%
# 2014 - 11%
# 2015 - 11%
# 2016 - 11%
# 2017 - 11%
# 2018 - 11%
# 2019 - 11%
# 2019.1 - 11%

# %%
co2=co2.dropna()

# %%
co2
# Out:
#              Country Name country_code                      Region  \
# 1             Afghanistan          AFG                  South Asia
# 2                  Angola          AGO          Sub-Saharan Africa
# 3                 Albania          ALB       Europe & Central Asia
# 4                 Andorra          AND       Europe & Central Asia
# 5    United Arab Emirates          ARE  Middle East & North Africa
# ..                    ...          ...                         ...
# 210                 Samoa          WSM         East Asia & Pacific
# 211           Yemen, Rep.          YEM  Middle East & North Africa
# 212          South Africa          ZAF          Sub-Saharan Africa
# 213                Zambia          ZMB          Sub-Saharan Africa
# 214              Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name       1990       1991       1992  \
# 1    CO2 emissions (metric tons per capita)   0.191745   0.167682   0.095958
# ...

# %%
res=pd.merge(co2, data_gdp_years_res, how="left", on=["Country Name", "Country Name"])
res
# Out:
#              Country Name country_code                      Region  \
# 0             Afghanistan          AFG                  South Asia
# 1                  Angola          AGO          Sub-Saharan Africa
# 2                 Albania          ALB       Europe & Central Asia
# 3                 Andorra          AND       Europe & Central Asia
# 4    United Arab Emirates          ARE  Middle East & North Africa
# ..                    ...          ...                         ...
# 178                 Samoa          WSM         East Asia & Pacific
# 179           Yemen, Rep.          YEM  Middle East & North Africa
# 180          South Africa          ZAF          Sub-Saharan Africa
# 181                Zambia          ZMB          Sub-Saharan Africa
# 182              Zimbabwe          ZWE          Sub-Saharan Africa
#
#                            Indicator Name_x     1990_x     1991_x     1992_x  \
# 0    CO2 emissions (metric tons per capita)   0.191745   0.167682   0.095958
# ...

# %%
res.to_csv(r'A:\kbtu\result.csv')
